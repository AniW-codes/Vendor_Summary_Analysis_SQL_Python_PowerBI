# %% [markdown]
# ## EDA
#
# Understanding the dataset to explore how data is present in DB and if there is a need to create agregated tables that can help with :
# 1. Vendor selection for profitability.
# 2. Product pricing optimisation.

# %%
# %pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine

# %%
import psycopg2

# %%
import pandas as pd

# %%
from sqlalchemy import create_engine, inspect

engine = create_engine('postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres')

inspector = inspect(engine)
tables = inspector.get_table_names(schema='public')

print(tables)
# Out:
# ['begin_inventory', 'end_inventory', 'purchases', 'purchase_prices', 'sales', 'vendor_invoice', 'products', 'vendor_sales_summary', 'walmart', 'cars', 'employee']

# %%
conn  = psycopg2.connect(host = 'localhost',
                         port = 5432, database = 'postgres',user = 'postgres',
                         password = 'Mosalah11!')

# %%
pd.read_sql("select count(*) from vendor_invoice",conn)
# Out:
# C:\Users\Aniruddha\AppData\Local\Temp\ipykernel_36116\3325911691.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql("select count(*) from vendor_invoice",conn)
#    count
# 0   5543

# %%
#All list of records in all tabls

for table in tables:
    print("-"*50, f"{table}","-"*50)
    count = pd.read_sql(f"select count(*) as Count from {table}", con=conn)['count'].values[0]
    print(f"Count of Records:",count)
    display(pd.read_sql(f"select * from {table} limit 5;", con=conn))
# Out:
# C:\Users\Aniruddha\AppData\Local\Temp\ipykernel_36116\2698725926.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   count = pd.read_sql(f"select count(*) as Count from {table}", con=conn)['count'].values[0]
# -------------------------------------------------- begin_inventory --------------------------------------------------
# Count of Records: 206529
# C:\Users\Aniruddha\AppData\Local\Temp\ipykernel_36116\2698725926.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   display(pd.read_sql(f"select * from {table} limit 5;", con=conn))
#          InventoryId  Store          City  Brand                  Description  \
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")
vendor_invoice = pd.read_sql('SELECT * FROM vendor_invoice where "VendorNumber" = 4466', con=engine)

# %%
vendor_invoice
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE    2024-02-09      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE    2024-02-17      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE    2024-03-01      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE    2024-03-07      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE    2024-03-12      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE    2024-03-16      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE    2024-03-23      9244
# 12          4466  AMERICAN VINTAGE BEVERAGE    2024-03-31      9371
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")
purchases = pd.read_sql('SELECT * FROM purchases where "VendorNumber" = 4466', con=engine)

# %%
purchases
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")
purchase_prices = pd.read_sql('SELECT * FROM purchase_prices where "VendorNumber" = 4466', con=engine)

# %%
purchase_prices
# Out:
#    Brand                   Description  Price    Size  Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL  1750.0               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL  1750.0               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL  1750.0               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
from sqlalchemy import create_engine

engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")
sales = pd.read_sql('SELECT * FROM sales where "VendorNo" = 4466', con=engine)

# %%
sales
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4     1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 9448     81_PEMBROKE_5255     81   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9449     81_PEMBROKE_5255     81   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9450     81_PEMBROKE_5255     81   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9451     9_BLACKPOOL_3140      9   3140      TGI Fridays Orange Dream  1.75L
# 9452     9_BLACKPOOL_3140      9   3140      TGI Fridays Orange Dream  1.75L
#
# ...

# %%
purchases.groupby(['Brand','PurchasePrice'])[['Quantity','Dollars']].sum()
# Out:
#                      Quantity   Dollars
# Brand PurchasePrice
# 3140  11.19              4640  51921.60
# 5215  9.41               4923  46325.43
# 5255  9.35               6215  58110.25

# %%
purchase_prices
#Information on what purchases were being made can be fetched from 'purchases' table.
# Out:
#    Brand                   Description  Price    Size  Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL  1750.0               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL  1750.0               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL  1750.0               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
vendor_invoice['PONumber'].nunique()
# Out:
# 55

# %%
vendor_invoice.shape
# Out:
# (55, 10)

# %%
#PurchasePrice + Vendor Invoice = Purchases

# %%
sales.head()
# Out:
#            InventoryId  Store  Brand                   Description   Size  \
# 0  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4  1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
#
#    SalesQuantity  SalesDollars  SalesPrice   SalesDate  Volume  \
# 0              1         12.99       12.99  2024-01-09  1750.0
# 1              1         12.99       12.99  2024-01-12  1750.0
# 2              1         12.99       12.99  2024-01-15  1750.0
# 3              1         12.99       12.99  2024-01-21  1750.0
# 4              1         12.99       12.99  2024-01-23  1750.0
#
#    Classification  ExciseTax  VendorNo                   VendorName
# 0               1       1.84      4466  AMERICAN VINTAGE BEVERAGE
# ...

# %%
sales.groupby('Brand')[['SalesDollars','SalesPrice','SalesQuantity']].sum()
# Out:
#        SalesDollars  SalesPrice  SalesQuantity
# Brand
# 3140       50531.10    30071.85           3890
# 5215       60416.49    41542.02           4651
# 5255       79187.04    51180.60           6096

# %% [markdown]
# - Purchases table consists of actual purchase data, inc date of purchase, brand purchased by vendors, amount paid and qty purchased.
# - PurchasePrice column is derived from Purchase_Price table which provides product wise actual and purchase prices. Combo of vendor and brand is unique.
# - Vendor_Invoice table aggregates data from purchases table, summarizing qty and dollar amounts, along with additional column for freight. The table maintains uniqueness based on vendor and PO number.
# - Sales table captures actual sales transactions, detailing purchased brands by vendors, qty sold, SP and revenue earned.

# %% [markdown]
# ## Creating a summary table containing:
# 1. Purchase transactions made by vendors.
# 2. sales transaction data.
# 3. freight cost for each vendor.
# 4. actual product prices from vendors.

# %%
vendor_invoice.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'InvoiceDate', 'PONumber', 'PODate',
#        'PayDate', 'Quantity', 'Dollars', 'Freight', 'Approval'],
#       dtype='object')

# %%
from sqlalchemy import create_engine
try:
    engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")
    freight_summary = pd.read_sql("""select "VendorNumber", sum("Freight") as freightcost
                                from vendor_invoice
                                group by "VendorNumber"
                                  """, con=engine)
except Exception as e:
    print(f'{e}')

# %%
freight_summary
# Out:
#      VendorNumber  freightcost
# 0            7255       648.71
# 1            1439         0.27
# 2            9751        24.53
# 3            6830       360.29
# 4            1587      6070.09
# ..            ...          ...
# 121          9625      1933.19
# 122          7154       432.37
# 123          1392     79528.99
# 124          1189       609.39
# 125         90017        80.03
#
# [126 rows x 2 columns]

# %%
purchase_prices.columns
# Out:
# Index(['Brand', 'Description', 'Price', 'Size', 'Volume', 'Classification',
#        'PurchasePrice', 'VendorNumber', 'VendorName'],
#       dtype='object')

# %%
purchases.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'VendorNumber',
#        'VendorName', 'PONumber', 'PODate', 'ReceivingDate', 'InvoiceDate',
#        'PayDate', 'PurchasePrice', 'Quantity', 'Dollars', 'Classification'],
#       dtype='object')

# %%
from sqlalchemy import create_engine
try:
    engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")
    purchase_summary = pd.read_sql("""select 
                                  pp."VendorNumber", pp."VendorName",pp."Brand",pp."PurchasePrice",
                                  pp."Volume",
                                  pp."Price" as actual_price,
                                  SUM(p."Quantity") as total_purchase_qty,
                                  SUM(p."Dollars") as total_purchase_dollars
                                from purchases as p
                                  join purchase_prices as pp
                                  on p."Brand" = pp."Brand"
                                   where pp."PurchasePrice" > 0
                                group by pp."VendorNumber", pp."VendorName",pp."Brand",pp."PurchasePrice",
                                  pp."Volume",pp."Price"
                                order by total_purchase_dollars
                                  """, con=engine)
except Exception as e:
    print(f'{e}')

# %%
purchase_summary
# Out:
#        VendorNumber                   VendorName  Brand  PurchasePrice  \
# 0              7245  PROXIMO SPIRITS INC.          3065           0.71
# 1              3960  DIAGEO NORTH AMERICA INC      6127           1.47
# 2              3924  HEAVEN HILL DISTILLERIES      9123           0.74
# 3              8004  SAZERAC CO INC                5683           0.39
# 4              9815  WINE GROUP INC                8527           1.32
# ...             ...                          ...    ...            ...
# 10658          3960  DIAGEO NORTH AMERICA INC      3545          21.89
# 10659          3960  DIAGEO NORTH AMERICA INC      4261          16.17
# 10660         17035  PERNOD RICARD USA             8068          18.24
# 10661          4425        MARTIGNETTI COMPANIES   3405          23.19
# 10662          1128  BROWN-FORMAN CORP             1233          26.27
#
#        Volume  actual_price  total_purchase_qty  total_purchase_dollars
# ...

# %%
sales.columns
# Out:
# Index(['InventoryId', 'Store', 'Brand', 'Description', 'Size', 'SalesQuantity',
#        'SalesDollars', 'SalesPrice', 'SalesDate', 'Volume', 'Classification',
#        'ExciseTax', 'VendorNo', 'VendorName'],
#       dtype='object')

# %%
from sqlalchemy import create_engine
try:
    engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")
    sales_summary = pd.read_sql("""select 
                                  "VendorNo","Brand",
                                  SUM("SalesDollars") as total_sales_dollars,
                                SUM("SalesPrice") as total_sales_price,
                                SUM("SalesQuantity") as total_sales_qty,
                                SUM("ExciseTax") as excisetax
                                from sales
                                group by "VendorNo","Brand"
                                order by total_sales_dollars
                                  """, con=engine)
except Exception as e:
    print(f'{e}')

# %%
sales_summary
# Out:
#        VendorNo  Brand  total_sales_dollars  total_sales_price  \
# 0          8004   5287                 0.98               0.98
# 1          9206   2773                 0.99               0.99
# 2          3924   9123                 1.98               0.99
# 3          3252   3933                 1.98               0.99
# 4         10050   3623                 1.98               1.98
# ...         ...    ...                  ...                ...
# 11267      3960   3545           4223107.62          545778.28
# 11268      3960   4261           4475972.88          420050.01
# 11269     17035   8068           4538120.60          461140.15
# 11270      4425   3405           4819073.49          561512.37
# 11271      1128   1233           5101919.51          672819.31
#
#        total_sales_qty  excisetax
# 0                  2.0       0.10
# 1                  1.0       0.05
# 2                  2.0       0.10
# 3                  2.0       0.10
# ...

# %%
from sqlalchemy import create_engine
try:
    engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")
    final_table = pd.read_sql("""SELECT pp."VendorNumber",
                                pp."Brand",
                                pp."Price" as actual_price,
                                pp."PurchasePrice",
                                SUM(s."SalesDollars") as total_sales_dollars,
                                SUM(s."SalesPrice") as total_sales_price,
                                SUM(s."SalesQuantity") as total_sales_quantity,
                                SUM(s."ExciseTax") as total_excise_tax,
                                SUM(vi."Quantity") as total_purchased_quantity,
                                SUM(vi."Dollars") as total_purchase_dollars,
                                SUM(vi."Freight") as total_frieght_cost
                                FROM purchase_prices as pp
                                JOIN sales as s
                                ON pp."VendorNumber" = s."VendorNo"
                                AND pp."Brand" = s."Brand"
                                JOIN vendor_invoice as vi
                                ON pp."VendorNumber" = vi."VendorNumber"
                                GROUP BY pp."VendorNumber", pp."Brand", pp."PurchasePrice",
                                pp."Price"
                              """, con=engine)
except Exception as e:
    print(f'{e}')

# %%
final_table
# Out:
#        VendorNumber  Brand  actual_price  PurchasePrice  total_sales_dollars  \
# 0                 2  90085         36.99          23.86         2.663280e+03
# 1                 2  90609         24.99          17.00         2.399040e+03
# 2                60    771         14.99          11.44         2.465855e+04
# 3                60   3979         20.99          16.27         2.340509e+06
# 4               105   2529         29.99          23.25         1.439520e+04
# ...             ...    ...           ...            ...                  ...
# 11217        172662   4215         25.99          19.40         9.722859e+04
# 11218        173357   2804         44.99          32.14         2.834370e+05
# 11219        173357   3666         24.99          18.79         4.048380e+05
# 11220        173357   3848         30.99          23.30         8.367300e+03
# 11221        173357   3909         24.99          19.37         1.104308e+06
#
# ...

# %% [markdown]
# ## To optimise the query, we can form CTEs of all queries made till now to reduce time

# %%
from sqlalchemy import create_engine
try:
    engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")
    df_final = pd.read_sql_query(""" WITH freight_summary as 
                  (select "VendorNumber", sum("Freight") as freightcost
                                from vendor_invoice
                                group by "VendorNumber"
                  ),
                
          purchase_summary as (select 
                                  pp."VendorNumber", pp."VendorName",pp."Brand",pp."Description",
                                 pp."PurchasePrice",
                                  pp."Volume",
                                  pp."Price" as actual_price,
                                  SUM(p."Quantity") as total_purchase_qty,
                                  SUM(p."Dollars") as total_purchase_dollars
                                from purchases as p
                                  join purchase_prices as pp
                                  on p."Brand" = pp."Brand"
                                   where pp."PurchasePrice" > 0
                                group by pp."VendorNumber", pp."VendorName",pp."Brand",pp."Description",
                                 pp."PurchasePrice",
                                  pp."Volume",pp."Price"
                                order by total_purchase_dollars
                  ),

          sales_summary as (select 
                                  "VendorNo","Brand",
                                  SUM("SalesDollars") as total_sales_dollars,
                                SUM("SalesPrice") as total_sales_price,
                                SUM("SalesQuantity") as total_sales_qty,
                                SUM("ExciseTax") as excisetax
                                from sales
                                group by "VendorNo","Brand"
                  )

                    SELECT 
                    ps."VendorNumber",
                    ps."VendorName",
                    ps."Brand",
                    ps."Description",
                    ps."PurchasePrice",
                    actual_price,
                    ps."Volume",
                    total_purchase_qty,
                    total_purchase_dollars,
                    total_sales_dollars,
                    total_sales_price,
                    total_sales_qty,
                    excisetax,
                    fs.freightcost
                    FROM purchase_summary as ps
                    LEFT JOIN sales_summary as ss
                    ON ps."VendorNumber" = ss."VendorNo"
                      AND ps."Brand" = ss."Brand"
                    LEFT JOIN freight_summary as fs
                    ON ps."VendorNumber" = fs."VendorNumber"
                    ORDER BY ps.total_purchase_dollars DESC""",con=engine)
    
except Exception as e:
    print(f'{e}')

# %%
df_final
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10658          9815  WINE GROUP INC                8527
# 10659          8004  SAZERAC CO INC                5683
# 10660          3924  HEAVEN HILL DISTILLERIES      9123
# 10661          3960  DIAGEO NORTH AMERICA INC      6127
# 10662          7245  PROXIMO SPIRITS INC.          3065
#
#                        Description  PurchasePrice  actual_price  Volume  \
# 0          Jack Daniels No 7 Black          26.27         36.99  1750.0
# 1            Tito's Handmade Vodka          23.19         28.99  1750.0
# 2                 Absolut 80 Proof          18.24         24.99  1750.0
# ...

# %% [markdown]
# ## The above query generates a vendor wise sales and purchase summary, which is valuable for:
#
# Performance Optimazation:
# 1. Query involves heavy joins and aggregations on large datasets like purchases and sales.
# 2. Storing pre-aggregated results avoids repeated expensive computations.
# 3. Helps in analysing sales, purchases and pricing for different brands and vendors.
# 4. future benefits involves faster report generation and dashboarding.
# 5. Instead of running expensive queries each time, dashboard can be generated using "df" quickly.

# %%
df_final.dtypes
# Out:
# VendorNumber                int64
# VendorName                 object
# Brand                       int64
# Description                object
# PurchasePrice             float64
# actual_price              float64
# Volume                    float64
# total_purchase_qty        float64
# total_purchase_dollars    float64
# total_sales_dollars       float64
# total_sales_price         float64
# total_sales_qty           float64
# excisetax                 float64
# freightcost               float64
# dtype: object

# %%
df_final.isnull().sum()
# Out:
# VendorNumber                0
# VendorName                  0
# Brand                       0
# Description                 0
# PurchasePrice               0
# actual_price                0
# Volume                      0
# total_purchase_qty          0
# total_purchase_dollars      0
# total_sales_dollars       190
# total_sales_price         190
# total_sales_qty           190
# excisetax                 190
# freightcost                 0
# dtype: int64

# %%
df_final.fillna(0,inplace=True)

# %%
df_final.isnull().sum()
# Out:
# VendorNumber              0
# VendorName                0
# Brand                     0
# Description               0
# PurchasePrice             0
# actual_price              0
# Volume                    0
# total_purchase_qty        0
# total_purchase_dollars    0
# total_sales_dollars       0
# total_sales_price         0
# total_sales_qty           0
# excisetax                 0
# freightcost               0
# dtype: int64

# %%
df_final['VendorName'].unique()
# Out:
# array(['BROWN-FORMAN CORP          ', 'MARTIGNETTI COMPANIES',
#        'PERNOD RICARD USA          ', 'DIAGEO NORTH AMERICA INC   ',
#        'BACARDI USA INC            ', 'JIM BEAM BRANDS COMPANY    ',
#        'MAJESTIC FINE WINES        ', 'ULTRA BEVERAGE COMPANY LLP ',
#        'STOLI GROUP,(USA) LLC      ', 'PROXIMO SPIRITS INC.       ',
#        'MOET HENNESSY USA INC      ', 'CAMPARI AMERICA            ',
#        'SAZERAC CO INC             ', 'CONSTELLATION BRANDS INC   ',
#        'M S WALKER INC             ', 'SAZERAC NORTH AMERICA INC. ',
#        'PALM BAY INTERNATIONAL INC ', 'REMY COINTREAU USA INC     ',
#        'SIDNEY FRANK IMPORTING CO  ', 'E & J GALLO WINERY         ',
#        'WILLIAM GRANT & SONS INC   ', 'HEAVEN HILL DISTILLERIES   ',
#        'DISARONNO INTERNATIONAL LLC', 'EDRINGTON AMERICAS         ',
#        'CASTLE BRANDS CORP.        ', 'SOUTHERN WINE & SPIRITS NE ',
#        'STE MICHELLE WINE ESTATES  ', 'TRINCHERO FAMILY ESTATES   ',
# ...

# %%
df_final['VendorName'].str.strip()
# Out:
# 0               BROWN-FORMAN CORP
# 1           MARTIGNETTI COMPANIES
# 2               PERNOD RICARD USA
# 3        DIAGEO NORTH AMERICA INC
# 4        DIAGEO NORTH AMERICA INC
#                    ...
# 10658              WINE GROUP INC
# 10659              SAZERAC CO INC
# 10660    HEAVEN HILL DISTILLERIES
# 10661    DIAGEO NORTH AMERICA INC
# 10662        PROXIMO SPIRITS INC.
# Name: VendorName, Length: 10663, dtype: object

# %%
df_final['VendorName'] = df_final['VendorName'].str.strip()

# %%
df_final['Description'].unique()
# Out:
# array(['Jack Daniels No 7 Black', "Tito's Handmade Vodka",
#        'Absolut 80 Proof', ..., 'Crown Royal Apple',
#        'Concannon Glen Ellen Wh Zin', 'The Club Strawbry Margarita'],
#       shape=(9651,), dtype=object)

# %% [markdown]
# ## Creating extra columns for better analysis

# %%
df_final['grossprofit'] = df_final['total_sales_dollars']- df_final['total_purchase_dollars']
df_final['profitmargin'] = (df_final['grossprofit']/df_final['total_sales_dollars'])*100
df_final['stockturnover'] = (df_final['total_sales_qty']/df_final['total_purchase_qty'])
df_final['sales_to_purchase_ratio'] = (df_final['total_sales_dollars']/df_final['total_purchase_dollars'])

# %%
df_final
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10658          9815            WINE GROUP INC   8527
# 10659          8004            SAZERAC CO INC   5683
# 10660          3924  HEAVEN HILL DISTILLERIES   9123
# 10661          3960  DIAGEO NORTH AMERICA INC   6127
# 10662          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  actual_price  Volume  \
# 0          Jack Daniels No 7 Black          26.27         36.99  1750.0
# 1            Tito's Handmade Vodka          23.19         28.99  1750.0
# 2                 Absolut 80 Proof          18.24         24.99  1750.0
# ...

# %%
df_final[df_final['grossprofit']<0]
# Out:
#        VendorNumber                VendorName  Brand  \
# 65             1128         BROWN-FORMAN CORP   5299
# 303            3960  DIAGEO NORTH AMERICA INC   2244
# 308            1128         BROWN-FORMAN CORP   5297
# 331            3960  DIAGEO NORTH AMERICA INC   3214
# 369            1128         BROWN-FORMAN CORP   5296
# ...             ...                       ...    ...
# 10599          9552            M S WALKER INC  24820
# 10605          5612   MILTONS DISTRIBUTING CO  23568
# 10609          3960  DIAGEO NORTH AMERICA INC   4397
# 10631          9815            WINE GROUP INC  13875
# 10643          5612   MILTONS DISTRIBUTING CO  17444
#
#                         Description  PurchasePrice  actual_price  Volume  \
# 65                 Southern Comfort          15.26         21.99  1750.0
# 303             Crown Royal Vanilla          17.90         23.99   750.0
# 308                Southern Comfort          10.76         13.99   750.0
# ...

# %%
df_final.duplicated().sum()
# Out:
# np.int64(0)

# %%
from sqlalchemy import create_engine, text

# Create SQLAlchemy engine
engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")

# SQL query to create the table
create_table_query = """
CREATE TABLE IF NOT EXISTS vendor_sales_summary (
    "VendorNumber"                INT,
    "VendorName"                  VARCHAR(255),
    "Brand"                       INT,
    "Description"                 VARCHAR(255),
    "PurchasePrice"               FLOAT,
    "actual_price"                FLOAT,
    "Volume"                      FLOAT,
    "total_purchase_qty"          FLOAT,
    "total_purchase_dollars"      FLOAT,
    "total_sales_dollars"         FLOAT,
    "total_sales_price"           FLOAT,
    "total_sales_qty"             FLOAT,
    "excisetax"                   FLOAT,
    "frieghtcost"                 FLOAT,
    "grossprofit"                 FLOAT,
    "profitmargin"                FLOAT,
    "stockturnover"               FLOAT,
    "sales_to_purchase_ratio"     FLOAT,
    PRIMARY KEY ("VendorNumber", "Brand")
);
"""

# Execute using SQLAlchemy engine
try:
    with engine.connect() as conn:
        conn.execute(text(create_table_query))
        conn.commit()
        print("✅ Table created successfully using SQLAlchemy.")
except Exception as e:
    print(f"❌ Error during table creation: {e}")
# Out:
# ✅ Table created successfully using SQLAlchemy.

# %%
from sqlalchemy import create_engine
try:
    engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")
    pd.read_sql("""Select * from vendor_sales_summary;
    """,con=engine)
except Exception as e:
    print(f"Error at: {e}")

# %%
pd.read_sql("""Select * from vendor_sales_summary""",con=engine)
# Out:
#        index  VendorNumber                VendorName  Brand  \
# 0          0          1128         BROWN-FORMAN CORP   1233
# 1          1          4425     MARTIGNETTI COMPANIES   3405
# 2          2         17035         PERNOD RICARD USA   8068
# 3          3          3960  DIAGEO NORTH AMERICA INC   4261
# 4          4          3960  DIAGEO NORTH AMERICA INC   3545
# ...      ...           ...                       ...    ...
# 10658  10658          9815            WINE GROUP INC   8527
# 10659  10659          8004            SAZERAC CO INC   5683
# 10660  10660          3924  HEAVEN HILL DISTILLERIES   9123
# 10661  10661          3960  DIAGEO NORTH AMERICA INC   6127
# 10662  10662          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  actual_price  Volume  \
# 0          Jack Daniels No 7 Black          26.27         36.99  1750.0
# 1            Tito's Handmade Vodka          23.19         28.99  1750.0
# ...

# %%
#Writing data from df into database in SQL
from sqlalchemy import create_engine
try:
    engine = create_engine("postgresql+psycopg2://postgres:Mosalah11!@localhost:5432/postgres")
    df_final.to_sql('vendor_sales_summary',con=engine,if_exists='replace',method='multi',chunksize=1000)

    print("Data written to PostgreSQL successfully.")

except Exception as e:
    print(f"Error at: {e}")
# Out:
# Data written to PostgreSQL successfully.
